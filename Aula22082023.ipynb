# %% [markdown]
# <a href="https://colab.research.google.com/github/deboradac/TesteDiretoColab/blob/main/Aula22082023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Olá mundo, turma de ADS!');
# Out:
# Olá mundo, turma de ADS!

# %%
#Pedindo ao usuário que indique a saudação com o comando input()
saudacao = input("Indique a saudação. Exemplo: Oi, E aí, Olá: ")

#Pedindo ao usuário que indique a pessoa cumprimentada com input()
nome = input("Indique a pessoa cumprimentada: ")

#imprimindo o que o usuário escreveu com novas condições
if (nome == "Alan Dantas"):
  print("Você é o professor do curso de Analytics para Estratégia de Negócios!")
else:
  print("! você é estudante do curso de Analytics para Estratégia de Negócios!")
# Out:
# Indique a saudação. Exemplo: Oi, E aí, Olá: oi
# Indique a pessoa cumprimentada: Alan Dantas
# Você é o professor do curso de Analytics para Estratégia de Negócios!

# %%
from google.colab import drive
drive.mount('/content/drive')
